# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from scipy.io import arff

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/My Drive/Introduction to data mining-project-04/History_of_Mass_Shootings_in_the_USA.csv')

# %%
data.head()
# Out:
#          Date          City        State  Dead  Injured  Total  \
# 0  31-07-2022       Decatur     Illinois     1        3      4
# 1  31-07-2022      Hartford  Connecticut     0        4      4
# 2  31-07-2022  Indianapolis      Indiana     0        4      4
# 3  31-07-2022       Detroit     Michigan     1        7      8
# 4  31-07-2022       Orlando      Florida     0        7      7
#
#                                          Description
# 0  Four teenagers, one of whom died, were shot at...
# 1  Four people, including a teenager, were shot i...
# 2  Four people were shot after a fight in the Bro...
# 3  One person was killed, and seven others were i...
# 4  Seven people were shot when someone opened fir...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712 entries, 0 to 2711
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         2712 non-null   object
#  1   City         2712 non-null   object
#  2   State        2712 non-null   object
#  3   Dead         2712 non-null   int64
#  4   Injured      2712 non-null   int64
#  5   Total        2712 non-null   int64
#  6   Description  2712 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 148.4+ KB

# %%
data.isnull().sum()
# Out:
# Date           0
# City           0
# State          0
# Dead           0
# Injured        0
# Total          0
# Description    0
# dtype: int64

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
data.to_csv('/content//Cleaned_data.csv',index=False)

# %%
data.shape
# Out:
# (2712, 7)

# %%
data.columns
# Out:
# Index(['Date', 'City', 'State', 'Dead', 'Injured', 'Total', 'Description'], dtype='object')

# %%
data.sample(15)
# Out:
#             Date            City       State  Dead  Injured  Total  \
# 1657  17-03-2020       Baltimore       Maryl     0        7      7
# 1683  25-02-2020       Lafayette   Louisiana     0        6      6
# 617   25-09-2021           Utica    New York     0        4      4
# 744   21-07-2021         Adelphi       Maryl     1        4      5
# 985   04-04-2021        Beaumont       Texas     0        4      4
# 211   15-05-2022    Laguna Woods  California     1        5      6
# 1992  16-06-2019      Louisville    Kentucky     1        6      7
# 259   23-04-2022  San Bernardino  California     1        4      5
# 68    08-07-2022         Detroit    Michigan     0        4      4
# 853   04-06-2021   New York City    New York     4        0      4
# 1061  26-02-2021         Houston       Texas     1        5      6
# 2278  02-10-2018     Paintsville    Kentucky     5        0      5
# 174   31-05-2022            Waco       Texas     0        4      4
# ...

# %%
old=data.sort_values(by='Date',ascending=True).head(15)
old
# Out:
#             Date           City           State  Dead  Injured  Total  \
# 2516  01-01-2018     Huntsville         Alabama     1        3      4
# 2194  01-01-2019       Columbia  South Carolina     0        5      5
# 2193  01-01-2019    Tallahassee         Florida     0        5      5
# 1749  01-01-2020      Cleveland            Ohio     0        4      4
# 1751  01-01-2020  Trujillo Alto     Puerto Rico     4        1      5
# 1750  01-01-2020     Huntington   West Virginia     0        7      7
# 1752  01-01-2020      St. Louis        Missouri     3        1      4
# 1136  01-01-2021     Sioux City            Iowa     1        4      5
# 1133  01-01-2021      Galesburg        Illinois     0        4      4
# 1134  01-01-2021       Amarillo           Texas     1        3      4
# 1135  01-01-2021     Fort Smith        Arkansas     0        7      7
# 440   01-01-2022     South Bend         Indiana     0        4      4
# ...

# %%
data.pop('Description')
# Out:
# 0       Four teenagers, one of whom died, were shot at...
# 1       Four people, including a teenager, were shot i...
# 2       Four people were shot after a fight in the Bro...
# 3       One person was killed, and seven others were i...
# 4       Seven people were shot when someone opened fir...
#                               ...
# 2707    Kansas City Massacre: Four law enforcement off...
# 2708    Murder of the Lawson family: Charles Lawson sh...
# 2709    Saint Valentine's Day Massacre: Seven members ...
# 2710    Columbine Mine Massacre: A fight broke out bet...
# 2711    Hanapepe Massacre: During a strike of Filipino...
# Name: Description, Length: 2712, dtype: object

# %%
data.describe()
# Out:
#               Dead      Injured        Total
# count  2712.000000  2712.000000  2712.000000
# mean      1.436578     4.401180     5.837021
# std       2.880447     8.532826    10.130793
# min       0.000000     0.000000     2.000000
# 25%       0.000000     3.000000     4.000000
# 50%       1.000000     4.000000     4.000000
# 75%       2.000000     5.000000     6.000000
# max      61.000000   411.000000   472.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def figure_size():
    f=plt.figure()
    f.set_figwidth(15)
    f.set_figheight(10)
    font={'family':'normal','size':15}

# %%
data.State.value_counts().plot(kind='bar',figsize=(20,5))
# Out:
# <Axes: xlabel='State'>

# %%
injured=data.sort_values(by=['Injured'])
injured
# Out:
#             Date           City     State  Dead  Injured  Total
# 2711  09-09-1924       Hanapepe    Hawaii    20        0     20
# 171   02-06-2022    Centerville     Texas     5        0      5
# 172   01-06-2022          Tulsa  Oklahoma     5        0      5
# 173   31-05-2022        Wyoming  Michigan     4        0      4
# 2710  21-11-1927         Serene  Colorado     6        0      6
# ...          ...            ...       ...   ...      ...    ...
# 2593  11-05-2009      Fort Hood     Texas    14       33     47
# 84    04-07-2022  Highland Park  Illinois     7       48     55
# 2538  06-12-2016        Orlando   Florida    50       58    108
# 2580  20-07-2012         Aurora  Colorado    12       70     82
# 2536  10-01-2017       Paradise    Nevada    61      411    472
#
# [2712 rows x 6 columns]

# %%
top=data.sort_values(by='Total',ascending=False).head(15)
top
# Out:
#             Date                City       State  Dead  Injured  Total
# 2536  10-01-2017            Paradise      Nevada    61      411    472
# 2538  06-12-2016             Orlando     Florida    50       58    108
# 2580  20-07-2012              Aurora    Colorado    12       70     82
# 84    04-07-2022       Highland Park    Illinois     7       48     55
# 2653  16-10-1991             Killeen       Texas    24       27     51
# 2607  16-04-2007          Blacksburg    Virginia    33       17     50
# 2532  11-05-2017  Sutherland Springs       Texas    27       22     49
# 2698  08-01-1966              Austin       Texas    17       31     48
# 2593  11-05-2009           Fort Hood       Texas    14       33     47
# 2116  08-03-2019             El Paso       Texas    23       23     46
# 2664  12-07-1987             Cayucos  California    43        0     43
# 2669  18-07-1984           San Diego  California    22       19     41
# ...

# %%
top.plot(kind='bar',x='City',y='Total')
# Out:
# <Axes: xlabel='City'>

# %%
top.plot(kind='bar',x='State',y='Dead')
# Out:
# <Axes: xlabel='State'>

# %%
import plotly.express as px

# %%
state_code = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
data['state_code'] = data.State.replace(state_code)

# %%
data.head(15)
# Out:
#           Date          City        State  Dead  Injured  Total state_code
# 0   31-07-2022       Decatur     Illinois     1        3      4         IL
# 1   31-07-2022      Hartford  Connecticut     0        4      4         CT
# 2   31-07-2022  Indianapolis      Indiana     0        4      4         IN
# 3   31-07-2022       Detroit     Michigan     1        7      8         MI
# 4   31-07-2022       Orlando      Florida     0        7      7         FL
# 5   31-07-2022    South Bend      Indiana     0        4      4         IN
# 6   30-07-2022      Wheeling     Illinois     0        5      5         IL
# 7   30-07-2022        Girard      Georgia     1        4      5         GA
# 8   30-07-2022        Monroe    Louisiana     1        3      4         LA
# 9   29-07-2022     Cleveland         Ohio     1        3      4         OH
# 10  29-07-2022   Albuquerque   New Mexico     1        4      5         NM
# ...

# %%
state_data=data.groupby(by=["state_code"]).sum()
state_data.head()
# Out:
#                                                          Date  \
# state_code
# AK          27-07-202219-06-202130-11-202004-08-202010-07-...
# AL          09-07-202227-05-202222-05-202209-05-202228-04-...
# AR          12-05-202221-04-202203-04-202219-03-202212-02-...
# AZ          03-07-202208-06-202205-06-202204-06-202229-05-...
# CA          24-07-202221-07-202210-07-202204-07-202204-07-...
#
#                                                          City  \
# state_code
# AK          Farmers LoopAnchoragePalmerAnchorageAnchorageB...
# AL          Jackson's GapAnnistonRiversideTuscaloosaBessem...
# AR          Hot SpringsMountain ViewParkin and WynneDumasL...
# AZ          SurpriseYumaMesaPhoenixPhoenixPhoenixGlendaleG...
# CA          Los AngelesLos AngelesDowneySacramentoOaklandO...
#
#                                                         State  Dead  Injured  \
# state_code
# AK                 AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaska    16       14
# ...

# %%
states_index = state_data.reset_index(level=0)
states_index.head()
# Out:
#   state_code                                               Date  \
# 0         AK  27-07-202219-06-202130-11-202004-08-202010-07-...
# 1         AL  09-07-202227-05-202222-05-202209-05-202228-04-...
# 2         AR  12-05-202221-04-202203-04-202219-03-202212-02-...
# 3         AZ  03-07-202208-06-202205-06-202204-06-202229-05-...
# 4         CA  24-07-202221-07-202210-07-202204-07-202204-07-...
#
#                                                 City  \
# 0  Farmers LoopAnchoragePalmerAnchorageAnchorageB...
# 1  Jackson's GapAnnistonRiversideTuscaloosaBessem...
# 2  Hot SpringsMountain ViewParkin and WynneDumasL...
# 3  SurpriseYumaMesaPhoenixPhoenixPhoenixGlendaleG...
# 4  Los AngelesLos AngelesDowneySacramentoOaklandO...
#
#                                                State  Dead  Injured  Total
# 0         AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaska    16       14     30
# 1  AlabamaAlabamaAlabamaAlabamaAlabamaAlabamaAlab...    78      261    339
# ...

# %%
fig = px.choropleth(states_index,
                    locations='state_code',
                    locationmode="USA-states",
                    scope="usa",
                    color='Total',
                    range_color = [1,1500],
                    )

fig.update_layout(
    title_text = 'Total Mass Shooting Deaths and Injuries between 1924-2022',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
injuries = data.groupby(['Injured']).size().sort_values(ascending = False).reset_index().rename(columns = {0:'Counts'})
injuries.head(10)
# Out:
#    Injured  Counts
# 0        4     968
# 1        3     513
# 2        5     354
# 3        2     229
# 4        6     154
# 5        0     122
# 6        1     114
# 7        7      96
# 8        8      35
# 9        9      25

# %%
figure_size()
sns.barplot(x=injuries.Injured[:10],y = injuries.Counts[:10]);
plt.show()
